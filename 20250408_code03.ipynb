# %%
from collections import deque

def solution(cony_loc, brown_loc):
    time = 0 
    queue = deque()
    queue.append((brown_loc, 0))
    visited = [{} for _ in range(20001)]
    
    while cony_loc < 20000:
        cony_loc += time
        print(f"시간: {time}, 코니 위치: {cony_loc}")
        
        if time in visited[cony_loc]:
            print(f"브라운이 코니를 잡음! 시간: {time}, 위치: {cony_loc}")
            return time
            
        current_queue_size = len(queue)
        print(f"현재 큐 크기: {current_queue_size}")
        
        for i in range(current_queue_size):
            current_position, current_time = queue.popleft()
            print(f"처리 중: 위치={current_position}, 시간={current_time}")
            
            # 뒤로 1칸
            new_position = current_position - 1
            new_time = current_time + 1
            if new_position >= 0 and new_time not in visited[new_position]:
                visited[new_position][new_time] = True
                queue.append((new_position, new_time))
                print(f"이동: {current_position} -> {new_position} (뒤로)")
            
            # 앞으로 1칸 (오류 수정)
            new_position = current_position + 1
            new_time = current_time + 1
            if new_position < 20001 and new_time not in visited[new_position]:
                visited[new_position][new_time] = True
                queue.append((new_position, new_time))
                print(f"이동: {current_position} -> {new_position} (앞으로)")
            
            # 두 배 이동
            new_position = current_position * 2
            new_time = current_time + 1
            if new_position < 20001 and new_time not in visited[new_position]:
                visited[new_position][new_time] = True
                queue.append((new_position, new_time))
                print(f"이동: {current_position} -> {new_position} (순간이동)")
                
        time += 1
        print("-------------------")
        
    return -1

c = 11
b = 2
print(f"결과: {solution(c, b)}")
# Out:
# 시간: 0, 코니 위치: 11
# 현재 큐 크기: 1
# 처리 중: 위치=2, 시간=0
# 이동: 2 -> 1 (뒤로)
# 이동: 2 -> 3 (앞으로)
# 이동: 2 -> 4 (순간이동)
# -------------------
# 시간: 1, 코니 위치: 12
# 현재 큐 크기: 3
# 처리 중: 위치=1, 시간=1
# 이동: 1 -> 0 (뒤로)
# 이동: 1 -> 2 (앞으로)
# 처리 중: 위치=3, 시간=1
# 이동: 3 -> 4 (앞으로)
# 이동: 3 -> 6 (순간이동)
# 처리 중: 위치=4, 시간=1
# 이동: 4 -> 3 (뒤로)
# 이동: 4 -> 5 (앞으로)
# 이동: 4 -> 8 (순간이동)
# -------------------
# 시간: 2, 코니 위치: 14
# 현재 큐 크기: 7
# 처리 중: 위치=0, 시간=2
# 이동: 0 -> 1 (앞으로)
# 이동: 0 -> 0 (순간이동)
# 처리 중: 위치=2, 시간=2
# 이동: 2 -> 3 (앞으로)
# 이동: 2 -> 4 (순간이동)
# 처리 중: 위치=4, 시간=2
# 이동: 4 -> 5 (앞으로)
# 이동: 4 -> 8 (순간이동)
# 처리 중: 위치=6, 시간=2
# 이동: 6 -> 7 (앞으로)
# 이동: 6 -> 12 (순간이동)
# 처리 중: 위치=3, 시간=2
# 이동: 3 -> 2 (뒤로)
# 이동: 3 -> 6 (순간이동)
# 처리 중: 위치=5, 시간=2
# 이동: 5 -> 10 (순간이동)
# 처리 중: 위치=8, 시간=2
# 이동: 8 -> 9 (앞으로)
# 이동: 8 -> 16 (순간이동)
# -------------------
# 시간: 3, 코니 위치: 17
# 현재 큐 크기: 13
# 처리 중: 위치=1, 시간=3
# 이동: 1 -> 0 (뒤로)
# 이동: 1 -> 2 (앞으로)
# 처리 중: 위치=0, 시간=3
# 이동: 0 -> 1 (앞으로)
# 처리 중: 위치=3, 시간=3
# 이동: 3 -> 4 (앞으로)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 시스템 한글 깨짐 방지를 위한 기본 폰트 설정
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['axes.unicode_minus'] = False

# # ✅ 1. 역량 항목 (영문 레이블)
# labels = [
#     "AI Literacy",
#     "Game Domain Understanding",
#     "Cross-functional Collaboration",
#     "Team-level Strategy & Execution",
#     "Global Communication",
#     "Research / Publication Experience"
# ]

# ✅ 2. 자기 평가 점수 (10점 만점 기준)
#    → 기준: 3~8년차 Associate의 상한 기대치에 대한 자기평가
scores = [7.5, 10, 8.5, 8, 9, 6.5]
scores += scores[:1]  # 마지막 점을 첫 점과 이어 닫기

# ✅ 3. 각 항목에 해당하는 각도 설정
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

# ✅ 4. 그래프 그리기
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(polar=True))
ax.plot(angles, scores, color='darkgreen', linewidth=2)
ax.fill(angles, scores, color='mediumseagreen', alpha=0.5)

# ✅ 5. 시각 요소 설정
ax.set_xticks(angles[:-1])
# ax.set_xticklabels(labels, fontsize=11)
ax.set_yticks([2, 4, 6, 8, 10])
ax.set_yticklabels(['2', '4', '6', '8', '10'], fontsize=10)
ax.set_ylim(0, 10)

# # ✅ 6. 제목과 주석
# ax.set_title("Self-assessed Competency Radar for DL Strategy & Ops", size=14, pad=20)
# ax.text(0, -1.5, "※ Scores based on the expected max level of a 3–8Y associate",
#         ha='center', va='center', fontsize=9)

plt.tight_layout()
plt.show()

plt.savefig("competency_radar.png", dpi=300)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\82106\Documents\GitHub\AvocadoFarm
